# %% [markdown]
# # PDF a Word Converter
#
# Este notebook de Google Colab permite cargar un archivo PDF, convertirlo a formato Word (.docx) para su edición y descargarlo automáticamente.
#
# ## Requisitos
# - `PyMuPDF` (fitz): Para leer y extraer texto del archivo PDF.
# - `python-docx`: Para crear y manipular el archivo de Word.
# - `google.colab`: Para manejar la carga y descarga de archivos en Google Colab.
#
# ## Pasos
# 1. Instalar las bibliotecas necesarias.
# 2. Definir la función para convertir PDF a Word.
# 3. Cargar el archivo PDF.
# 4. Convertir el archivo PDF a Word.
# 5. Descargar el archivo Word convertido.
#
# ## Autor
# [Tu Nombre]
#
# ## Fecha
# [Fecha de Creación]
# """
#
# # Instalación de las bibliotecas necesarias
# !pip install PyMuPDF python-docx
#
# # Importación de las bibliotecas
# import fitz  # PyMuPDF
# from docx import Document
# from google.colab import files
#
# def pdf_to_word(pdf_path):
#     """
#     Convierte un archivo PDF a formato Word (.docx).
#
#     Args:
#         pdf_path (str): Ruta del archivo PDF a convertir.
#
#     Returns:
#         str: Ruta del archivo Word generado.
#     """
#     # Abrir el PDF
#     pdf_document = fitz.open(pdf_path)
#     doc = Document()
#
#     # Iterar por cada página del PDF
#     for page_num in range(len(pdf_document)):
#         page = pdf_document.load_page(page_num)
#         text = page.get_text()
#
#         # Agregar el texto extraído al documento de Word
#         doc.add_paragraph(text)
#
#     # Guardar el documento de Word
#     word_path = pdf_path.replace('.pdf', '.docx')
#     doc.save(word_path)
#     return word_path
#
# # Subir archivo PDF
# uploaded = files.upload()
#
# for file_name in uploaded.keys():
#     # Convertir el archivo PDF a Word
#     word_file = pdf_to_word(file_name)
#
#     # Descargar el archivo Word convertido
#     files.download(word_file)

# %%
# !pip install pdf2docx
# !pip install pypdf2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 31.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=16bbf2f1225bf77373c153ec50bd254b3b3db85ad1a2043a58180f3a72cf55d0
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import fitz  # PyMuPDF
from docx import Document
from google.colab import files

def pdf_to_word(pdf_path):
    # Abrir el PDF
    pdf_document = fitz.open(pdf_path)
    doc = Document()

    # Iterar por cada página
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text = page.get_text()

        # Agregar texto al documento de Word
        doc.add_paragraph(text)

    # Guardar el documento de Word
    word_path = pdf_path.replace('.pdf', '.docx')
    doc.save(word_path)
    return word_path

# Subir archivo PDF
uploaded = files.upload()

for file_name in uploaded.keys():
    word_file = pdf_to_word(file_name)

    # Descargar el archivo Word convertido
    files.download(word_file)
# Out:
#      <input type="file" id="files-16817862-60ef-4aef-8c3d-34c9be599b2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16817862-60ef-4aef-8c3d-34c9be599b2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
